# %% [markdown]
# # Lego Sales Data Cleaning

# %% [markdown]
# Exploratory Data Analysis being performed on the data provided by lego.

# %% [markdown]
# Data was taken from github

# %%
#importing pandas library
import pandas as pd

# %% [markdown]
# Reading all the necessary datasets to be used to perform Analysis.

# %%
#reading all the necessary datasets using pandas 
df=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/lego_sets.csv")
theme=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/parent_themes.csv")
df.head(100)
# Out:
#     set_num                        name  year  num_parts    theme_name  \
# 0      00-1             Weetabix Castle  1970      471.0        Castle
# 1    0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2    0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3    0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4    0013-1          Space Mini-Figures  1979       12.0  Supplemental
# ..      ...                         ...   ...        ...           ...
# 95  10075-1      Spider-Man Action Pack  2002       25.0    Spider-Man
# 96  10076-1         TECHNIC Gear Wheels  2002       38.0       Technic
# 97  10077-1               TECHNIC Motor  2003       55.0       Technic
# 98  10078-1       Train Connection Wire  2003        1.0         Train
# 99  10079-1                     Snowman  2003       42.0     Christmas
#
#     parent_theme
# 0       Legoland
# 1           Town
# 2         Castle
# 3          Space
# 4          Space
# ...

# %% [markdown]
# Q1. what percentage of all the albums released were star wars themed?

# %%
merged[merged['set_num'].isnull()].shape
merged.head()
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1     Legoland  411        False
# 2     Legoland  411        False
# 3     Legoland  411        False
# 4     Legoland  411        False

# %%
merged=df.merge(theme,left_on="parent_theme",right_on="name")
merged.drop(columns="name_y",inplace= True)

licensed=merged[merged['is_licensed']]
licensed=licensed.dropna(subset='set_num')

licensed.isnull()
licensed.head()
# Out:
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# 3495      Star Wars Episode 1    Star Wars  158         True
# 3496  Star Wars Episode 4/5/6    Star Wars  158         True
# 3497  Star Wars Episode 4/5/6    Star Wars  158         True

# %%
starwars_force=licensed[licensed["parent_theme"]=="Star Wars"]
starwars_force.head(10)
# Out:
#       set_num                           name_x  year  num_parts  \
# 3493  10018-1                       Darth Maul  2001     1868.0
# 3494  10019-1      Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1          Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1    Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                       Cloud City  2003      707.0
# 3498  10129-1          Rebel Snowspeeder - UCS  2003     1456.0
# 3499  10131-1           TIE Fighter Collection  2004        NaN
# 3500  10134-1  Y-wing Attack Starfighter - UCS  2004        NaN
# 3501  10143-1                    Death Star II  2005        NaN
# 3502  10144-1                      Sandcrawler  2005     1679.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# 3495      Star Wars Episode 1    Star Wars  158         True
# ...

# %%
Force=int(starwars_force.shape[0]/licensed.shape[0]*100)
print(Force)
# Out:
# 51

# %% [markdown]
# # Here we get the insight that 51% of the albums released were star wars themed.

# %% [markdown]
# Q2.In which year was star wars not the most licensed album.

# %%
licensed_sort=licensed.sort_values('year')
licensed_sort['count']=1
sumed=licensed_sort.groupby(['year','parent_theme']).sum().reset_index()
sumed.head()
# Out:
#    year           parent_theme  \
# 0  1999              Star Wars
# 1  2000  Disney's Mickey Mouse
# 2  2000              Star Wars
# 3  2001           Harry Potter
# 4  2001              Star Wars
#
#                                              set_num  \
# 0  7161-17171-17140-17130-17128-17141-17121-17131...
# 1                     4165-14167-14166-14164-14178-1
# 2  7134-13341-17159-17144-17124-17115-17104-14151...
# 3  4723-14707-14722-14721-14709-14701-14702-14704...
# 4  7166-17186-165028-165030-165034-18007-18008-17...
#
#                                               name_x  num_parts  \
# 0  Gungan SubMos Espa PodraceX-wing FighterSnowsp...     1384.0
# 1  Minnie's Birthday PartyMickey's MansionMickey'...      405.0
# 2  A-wing FighterStar Wars #2 - Luke/Han/Boba Min...     2580.0
# 3  Diagon Alley ShopsHagrid's HutGryffindorHogwar...     1284.0
# 4  Imperial ShuttleWatto's JunkyardStar Wars Co-P...     2949.0
#
# ...

# %%
sumed_max=sumed.sort_values('count',ascending=False).drop_duplicates(['year'])
sumed_max.head()
# Out:
#     year  parent_theme                                            set_num  \
# 82  2017  Super Heroes  76075-1211701-130449-130521-17090470903-170902...
# 76  2016     Star Wars  75156-175157-175159-130279-175158-130602-13060...
# 67  2015     Star Wars  75099-1SW911506-1SW911508-1SW911509-1SW911511-...
# 59  2014     Star Wars  75046-175045-175044-175043-175039-175041-17504...
# 47  2012     Star Wars  66432-1comcon019-1comcon024-130058-166431-1949...
#
#                                                name_x  num_parts  \
# 82  Wonder Woman" Warrior BattleBatmanThe MilanoTh...    13123.0
# 76  Krennic’s Imperial ShuttleCaptain Rex’s AT-TED...     6934.0
# 67  Rey's Speeder™SnowspeederMini Slave 1Imperial ...    11410.0
# 59  Coruscant Police GunshipRepublic AV-7 Anti-Veh...     8293.0
# 47  Star Wars Super Pack 3 in 1 (9490, 9492, 9496)...     6769.0
#
#                                            theme_name     id  is_licensed  \
# ...

# %% [markdown]
# # we can see that in year 2017 star wars was not the most sold album
